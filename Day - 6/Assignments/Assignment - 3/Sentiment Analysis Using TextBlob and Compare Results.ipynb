# %% [markdown]
# # Sentiment Analysis Using TextBlob and Compare Results

# %%
from textblob import TextBlob

reviews = [
    "This movie was amazing",
    "I loved the acting",
    "Worst movie ever",
    "The story was boring",
    "Fantastic experience",
    "Not worth watching"
]

for review in reviews:

    sentiment = TextBlob(review)

    polarity = sentiment.sentiment.polarity

    if polarity > 0:
        label = "Positive"
    elif polarity < 0:
        label = "Negative"
    else:
        label = "Neutral"

    print("Review:", review)
    print("Polarity:", polarity)
    print("Sentiment:", label)
    print("-" * 40)
# Out:
# Review: This movie was amazing
# Polarity: 0.6000000000000001
# Sentiment: Positive
# ----------------------------------------
# Review: I loved the acting
# Polarity: 0.35
# Sentiment: Positive
# ----------------------------------------
# Review: Worst movie ever
# Polarity: -1.0
# Sentiment: Negative
# ----------------------------------------
# Review: The story was boring
# Polarity: -1.0
# Sentiment: Negative
# ----------------------------------------
# Review: Fantastic experience
# Polarity: 0.4
# Sentiment: Positive
# ----------------------------------------
# Review: Not worth watching
# Polarity: -0.15
# Sentiment: Negative
# ----------------------------------------
