# %% [markdown]
# # Use GRU Instead of LSTM for Sentiment Analysis

# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, Dense

vocab_size = 10000
max_length = 120

(X_train, y_train), (X_test, y_test) = imdb.load_data(
    num_words=vocab_size
)

X_train = pad_sequences(
    X_train,
    maxlen=max_length
)

X_test = pad_sequences(
    X_test,
    maxlen=max_length
)

model = Sequential([
    Embedding(vocab_size, 16, input_length=max_length),
    GRU(64),
    Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.fit(
    X_train,
    y_train,
    epochs=5,
    validation_split=0.2
)

loss, accuracy = model.evaluate(
    X_test,
    y_test
)

print("Test Accuracy:", accuracy)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# C:\Users\bandi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\embedding.py:103: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.7606 - loss: 0.4745 - val_accuracy: 0.8372 - val_loss: 0.3768
# Epoch 2/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.8887 - loss: 0.2820 - val_accuracy: 0.8504 - val_loss: 0.3644
# Epoch 3/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 29s 47ms/step - accuracy: 0.9222 - loss: 0.2092 - val_accuracy: 0.8550 - val_loss: 0.4025
# Epoch 4/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.9405 - loss: 0.1626 - val_accuracy: 0.8512 - val_loss: 0.3737
# Epoch 5/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.9559 - loss: 0.1254 - val_accuracy: 0.8358 - val_loss: 0.4649
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.8316 - loss: 0.4813
# Test Accuracy: 0.8316400051116943
